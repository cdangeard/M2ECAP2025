# %% [markdown]
# # TP Arbres & Algorithmes d'aggrégation

# %% [markdown]
# Chargez le jeu de données `forestfires.csv` disponible sur Moodle. Ce jeu de données contient des informations sur des incendies de forêt, y compris des variables météorologiques et des caractéristiques géographiques.

# %%
list.of.packages <- c("ggplot2", "rpart", "rpart.plot", "caret", "randomForest", "gbm", "xgboost", "lightgbm")
new.packages <- list.of.packages[!(list.of.packages %in% installed.packages()[,"Package"])]
if(length(new.packages)) install.packages(new.packages)
lapply(list.of.packages, require, character.only = TRUE)
# Out:
# Loading required package: ggplot2
#
# Loading required package: rpart
#
# Loading required package: rpart.plot
#
# Loading required package: caret
#
# Loading required package: lattice
#
# Loading required package: randomForest
#
# randomForest 4.7-1.2
#
# Type rfNews() to see new features/changes/bug fixes.
#
#
# Attaching package: ‘randomForest’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     margin
#
#
# Loading required package: gbm
#
# Loaded gbm 2.2.2
#
# This version of gbm is no longer under development. Consider transitioning to gbm3, https://github.com/gbm-developers/gbm3
#
# Loading required package: xgboost
#
# Loading required package: lightgbm
# [[1]]
# [1] TRUE
#
# [[2]]
# [1] TRUE
#
# [[3]]
# [1] TRUE
#
# [[4]]
# [1] TRUE
#
# [[5]]
# [1] TRUE
#
# [[6]]
# [1] TRUE
#
# [[7]]
# [1] TRUE
#
# [[8]]
# [1] TRUE

# %% [markdown]
# Créer vos echantillons d'entrainement et de test (70% / 30%). La variable cible est `area`, qui représente la superficie brûlée par l'incendie.

# %% [markdown]
# A l'aide du package [rpart](https://cran.r-project.org/web/packages/rpart/index.html), entraînez un arbre de régression pour prédire la variable `area` en utilisant les autres variables comme prédicteurs. Affichez l'arbre et interprétez les résultats. [pdfDoc](https://cran.r-project.org/web/packages/rpart/vignettes/longintro.pdf)

# %% [markdown]
# Evaluer la performance de votre modèle sur l'échantillon de test en utilisant des métriques telles que l'erreur quadratique moyenne (RMSE) et le coefficient de détermination (R²).

# %% [markdown]
# Entrainez maintenant un arbre profond

# %% [markdown]
# utilisez la fonction [prune](https://www.rdocumentation.org/packages/rpart/versions/4.1.24/topics/prune.rpart) pour élager votre arbre

# %% [markdown]
# A l'aide de la librairie [randomForest](https://cran.r-project.org/web/packages/randomForest/index.html), entraînez un modèle de forêt aléatoire

# %% [markdown]
# ## Modèles de Boosting
#
# **Question :**
# Des modèles de boosting (par exemple avec le package `gbm` et `xgboost`) pour prédire la variable `area`.

# %% [markdown]
# Avec le model [Xgboost](https://xgboost.readthedocs.io/en/latest/R-package/xgboost_introduction.html)

# %% [markdown]
# # Carret (Classification And REgression Training)
#
# Utilisez le package [caret](https://topepo.github.io/caret/) pour effectuer une validation croisée et optimiser les hyperparamètres de votre modèle de forêt aléatoire. Comparez les performances du modèle optimisé avec celles du modèle initial.
